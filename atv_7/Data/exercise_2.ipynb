# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import linkage
# from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import dendrogram
import scipy.io as sp
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
bird_small_mat = sp.loadmat('bird_small.mat').get('A', None)

# %%
bird_data = list()
for i in range(128):
    for j in range(128):
        bird_data.append(bird_small_mat_data[i][j])

# %%
kmeans_bird = KMeans(n_clusters=16)
kmeans_fit = kmeans_bird.fit(bird_data)

# %%
new_bird = []

centroids = np.rint(kmeans_fit.cluster_centers_).astype(int)
k = 0
for i in range(128):
    new_bird.append([])
    for j in range(128):
        new_bird[i].append(centroids[kmeans_bird.labels_[k]].tolist())
        k+=1

# %%
plt.imshow(new_bird)
